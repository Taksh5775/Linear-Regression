# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("50_Startups.csv")
df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df1['State'].value_counts()
# Out:
# California    17
# New York      17
# Florida       16
# Name: State, dtype: int64

# %%
sns.distplot(df1['R&D Spend'])
plt.show()
sns.histplot(df1['R&D Spend'])
plt.show()
sns.scatterplot(x=df1['R&D Spend'],y=df1['Profit'],style=df1['State'])
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df1['Administration'])
plt.show()
sns.histplot(df1['Administration'],shrink=2, multiple='layer')
plt.show()
sns.scatterplot(x=df1['Administration'],y=df1['Profit'],hue=df1['State'],palette='deep')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df1['Marketing Spend'])
plt.show()
sns.histplot(df1['Marketing Spend'])
plt.show()
sns.scatterplot(x=df1['Marketing Spend'],y=df1['Profit'],marker="D")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(df1['State'])
plt.show()
sns.scatterplot(x=df1['State'],y=df1['Profit'],hue=df1['State'])
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## spliting data

# %%
from sklearn.model_selection import train_test_split

# %%
X2 = df1[['Marketing Spend']]
y2= df1[['Profit']]

# %%
X2_train,X2_test, y2_train, y2_test = train_test_split(X2,y2,train_size=0.7, test_size=0.3, random_state=22)

# %%
X2_train
# Out:
#     Marketing Spend
# 23        304768.73
# 11        249744.55
# 9         304981.62
# 10        229160.95
# 37        197029.42
# 21        299737.29
# 7         323876.68
# 28        118148.20
# 40        172795.67
# 19             0.00
# 6         127716.82
# 17        282574.31
# 45          1903.93
# 2         407934.54
# 48             0.00
# 27        353183.81
# 15        261776.23
# 5         362861.36
# 42        148001.11
# 34        210797.67
# 39        174999.30
# 24        140574.81
# 14        256512.92
# 18        294919.57
# 29        107138.38
# 46        297114.46
# 31         88218.23
# 8         311613.29
# 20        298664.47
# 43         35534.17
# 38        185265.10
# 36        201126.82
# 0         471784.10
# 44         28334.72
# 4         366168.42

# %%
X2_test
# Out:
#     Marketing Spend
# 32         46085.25
# 12        249839.44
# 25        137962.62
# 47             0.00
# 33        214634.81
# 22        303319.26
# 3         383199.62
# 30         91131.24
# 26        134050.07
# 1         443898.53
# 35        205517.64
# 41        164470.71
# 16        264346.06
# 49         45173.06
# 13        252664.93

# %%
y2_train
# Out:
#        Profit
# 23  108733.99
# 11  144259.40
# 9   149759.96
# 10  146121.95
# 37   89949.14
# 21  111313.02
# 7   155752.60
# 28  103282.38
# 40   78239.91
# 19  122776.86
# 6   156122.51
# 17  125370.37
# 45   64926.08
# 2   191050.39
# 48   35673.41
# 27  105008.31
# 15  129917.04
# 5   156991.12
# 42   71498.49
# 34   96712.80
# 39   81005.76
# 24  108552.04
# 14  132602.65
# 18  124266.90
# 29  101004.64
# 46   49490.75
# 31   97483.56
# 8   152211.77
# 20  118474.03
# 43   69758.98
# 38   81229.06
# 36   90708.19
# 0   192261.83
# 44   65200.33
# 4   166187.94

# %%
from sklearn.linear_model import LinearRegression

# %%
lr1 = LinearRegression()

# %% [markdown]
# ## train a model

# %%
# lr.predict(X_test.iloc[0].values.reshape(1,1))

# %%
X2_train = np.array(X2_train)
X2_train = X2_train.reshape(-1,1)

# %%
y2_train = np.array(y2_train)
y2_train = y2_train.reshape(-1,1)

# %%
lr1.fit(X2_train,y2_train)
# Out:
# LinearRegression()

# %%
y2_pred = lr1.predict(X2_test)

# %%
y2_pred
# Out:
# array([[ 76358.18664605],
#        [120536.60394505],
#        [ 96279.23363014],
#        [ 66365.88461864],
#        [112903.46111252],
#        [132132.212384  ],
#        [149452.04211646],
#        [ 86125.15410751],
#        [ 95430.90620873],
#        [162612.90901973],
#        [110926.6569013 ],
#        [102026.77414363],
#        [123681.96018022],
#        [ 76160.40366806],
#        [121149.23270274]])

# %%
y2_test
# Out:
#        Profit
# 32   97427.84
# 12  141585.52
# 25  107404.34
# 47   42559.73
# 33   96778.92
# 22  110352.25
# 3   182901.99
# 30   99937.59
# 26  105733.54
# 1   191792.06
# 35   96479.51
# 41   77798.83
# 16  126992.93
# 49   14681.40
# 13  134307.35

# %% [markdown]
# ### evaluate model

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
score = r2_score(y2_test,y2_pred)

# %% [markdown]
# # score

# %%
# beta coefficient of YearsExperiance = beta1
lr1.coef_
# Out:
# array([[0.21682213]])

# %%
# beta coefficient of constant = beta0
lr1.intercept_
# Out:
# array([66365.88461864])

# %% [markdown]
# #### the equation is y = 66365.88 + 0.2168*X

# %%
pred = 66365.88 + 0.2168*46085

# %%
pred

# %% [markdown]
# ## check assumption on linear regression

# %%
y2_pred_train = lr1.predict(X2_train)
y2_pred_train
# Out:
# array([[132446.48955554],
#        [120516.02969322],
#        [132492.64881861],
#        [116053.04971565],
#        [109086.2229682 ],
#        [131355.56202205],
#        [136589.51595823],
#        [ 91983.02889787],
#        [103831.80969592],
#        [ 66365.88461864],
#        [ 94057.71745929],
#        [127634.24815589],
#        [ 66778.698775  ],
#        [154815.12013521],
#        [ 66365.88461864],
#        [142943.9502841 ],
#        [123124.76416806],
#        [145042.25728005],
#        [ 98455.80040539],
#        [112071.48424787],
#        [104309.60544438],
#        [ 96845.61422768],
#        [121983.56208749],
#        [130310.973714  ],
#        [ 89595.85628391],
#        [130786.87443705],
#        [ 85493.54907708],
#        [133930.54162783],
#        [131122.95090546],
#        [ 74070.47901562],
#        [106535.4580578 ],
#        [109974.62996018],
#        [168659.11767969],
#        [ 72509.47893791],
#        [145759.30107048]])

# %%
residual = y2_train - y2_pred_train
residual
# Out:
# array([[-23712.49955554],
#        [ 23743.37030678],
#        [ 17267.31118139],
#        [ 30068.90028435],
#        [-19137.0829682 ],
#        [-20042.54202205],
#        [ 19163.08404177],
#        [ 11299.35110213],
#        [-25591.89969592],
#        [ 56410.97538136],
#        [ 62064.79254071],
#        [ -2263.87815589],
#        [ -1852.618775  ],
#        [ 36235.26986479],
#        [-30692.47461864],
#        [-37935.6402841 ],
#        [  6792.27583194],
#        [ 11948.86271995],
#        [-26957.31040539],
#        [-15358.68424787],
#        [-23303.84544438],
#        [ 11706.42577232],
#        [ 10619.08791251],
#        [ -6044.073714  ],
#        [ 11408.78371609],
#        [-81296.12443705],
#        [ 11990.01092292],
#        [ 18281.22837217],
#        [-12648.92090546],
#        [ -4311.49901562],
#        [-25306.3980578 ],
#        [-19266.43996018],
#        [ 23602.71232031],
#        [ -7309.14893791],
#        [ 20428.63892952]])

# %% [markdown]
# ## 1. error terms are normally distributed

# %%
sns.distplot(residual)
plt.xlabel('residual')
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 2 and 4 assumption

# %%
sns.scatterplot(x=residual.squeeze(),y=y_pred_train.squeeze())
plt.xlabel('Marketing Spend')
plt.ylabel('Residual')
plt.title('Residual vs target')
plt.show()

# %%
X1 = df1[['R&D Spend']]
y1 = df1[['Profit']]

# %%
from sklearn.model_selection import train_test_split

# %%
# X_test.iloc[0].values.reshape(1,1)

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1,y1,train_size=0.7,test_size=0.3,random_state=21)

# %%
X1_train
# Out:
#     R&D Spend
# 33   55493.95
# 0   165349.20
# 13   91992.39
# 28   66051.52
# 49       0.00
# 40   28754.33
# 45    1000.23
# 48     542.05
# 46    1315.46
# 29   65605.48
# 37   44069.95
# 1   162597.70
# 27   72107.60
# 24   77044.01
# 32   63408.86
# 3   144372.41
# 26   75328.87
# 16   78013.11
# 42   23640.93
# 6   134615.46
# 18   91749.16
# 5   131876.90
# 12   93863.75
# 39   38558.51
# 20   76253.86
# 38   20229.59
# 36   28663.76
# 41   27892.92
# 8   120542.52
# 10  101913.08
# 34   46426.07
# 35   46014.02
# 4   142107.34
# 15  114523.61
# 9   123334.88

# %%
X1_test
# Out:
#     R&D Spend
# 7   130298.13
# 44   22177.74
# 43   15505.73
# 25   64664.71
# 14  119943.24
# 2   153441.51
# 23   67532.53
# 31   61136.38
# 17   94657.16
# 47       0.00
# 30   61994.48
# 21   78389.47
# 19   86419.70
# 11  100671.96
# 22   73994.56

# %%
y1_train
# Out:
#        Profit
# 33   96778.92
# 0   192261.83
# 13  134307.35
# 28  103282.38
# 49   14681.40
# 40   78239.91
# 45   64926.08
# 48   35673.41
# 46   49490.75
# 29  101004.64
# 37   89949.14
# 1   191792.06
# 27  105008.31
# 24  108552.04
# 32   97427.84
# 3   182901.99
# 26  105733.54
# 16  126992.93
# 42   71498.49
# 6   156122.51
# 18  124266.90
# 5   156991.12
# 12  141585.52
# 39   81005.76
# 20  118474.03
# 38   81229.06
# 36   90708.19
# 41   77798.83
# 8   152211.77
# 10  146121.95
# 34   96712.80
# 35   96479.51
# 4   166187.94
# 15  129917.04
# 9   149759.96

# %%
y1_test
# Out:
#        Profit
# 7   155752.60
# 44   65200.33
# 43   69758.98
# 25  107404.34
# 14  132602.65
# 2   191050.39
# 23  108733.99
# 31   97483.56
# 17  125370.37
# 47   42559.73
# 30   99937.59
# 21  111313.02
# 19  122776.86
# 11  144259.40
# 22  110352.25

# %%
from sklearn.linear_model import LinearRegression

# %%
lr2 = LinearRegression()

# %%
lr2.fit(X1_train,y1_train)
# Out:
# LinearRegression()

# %%
y1_pred = lr2.predict(X1_test)

# %%
y1_pred
# Out:
# array([[160777.98264777],
#        [ 68511.71016718],
#        [ 62818.0432034 ],
#        [104768.64885279],
#        [151941.470846  ],
#        [180527.75792329],
#        [107215.94914042],
#        [101757.69174117],
#        [130363.18808873],
#        [ 49585.97930509],
#        [102489.96516726],
#        [116480.89337846],
#        [123333.61920808],
#        [135496.01433655],
#        [112730.42629646]])

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
score = r2_score(y1_test,y1_pred)

# %%
score
# Out:
# 0.9588210688104886

# %%
lr2.coef_ # M
# Out:
# array([[0.85336607]])

# %%
lr2.intercept_ # C
# Out:
# array([49585.97930509])

# %% [markdown]
# ### Equation is y = 49585.98 + 0.8533*X
#
# #### X = R&D spend, y = Profit

# %%
pred = 49585.98 + 0.8533*130298.13

# %%
pred
# Out:
# 160769.374329

# %% [markdown]
# Assumptions

# %%
y1_pred_train = lr2.predict(X1_train)

# %%
y1_pred_train
# Out:
# array([[ 96942.63341746],
#        [190689.37656113],
#        [128089.16378196],
#        [105952.10545463],
#        [ 49585.97930509],
#        [ 74123.94894039],
#        [ 50439.54165095],
#        [ 50048.54638423],
#        [ 50708.54823772],
#        [105571.47005203],
#        [ 87193.77941482],
#        [188341.33981496],
#        [111120.15865388],
#        [115332.72346368],
#        [103696.9490717 ],
#        [172788.4956828 ],
#        [113869.08117954],
#        [116159.72052373],
#        [ 69760.34686957],
#        [164462.24558993],
#        [127881.59955235],
#        [162125.25140072],
#        [129686.11891382],
#        [ 82490.50351283],
#        [114658.43626216],
#        [ 66849.22505467],
#        [ 74046.65957528],
#        [ 73388.8508726 ],
#        [152452.87606543],
#        [136555.14403541],
#        [ 89204.41228358],
#        [ 88852.78279375],
#        [170855.56179487],
#        [147316.54248305],
#        [154835.78134929]])

# %%
residual2 = y1_train - y1_pred_train
residual2
# Out:
#           Profit
# 33   -163.713417
# 0    1572.453439
# 13   6218.186218
# 28  -2669.725455
# 49 -34904.579305
# 40   4115.961060
# 45  14486.538349
# 48 -14375.136384
# 46  -1217.798238
# 29  -4566.830052
# 37   2755.360585
# 1    3450.720185
# 27  -6111.848654
# 24  -6780.683464
# 32  -6269.109072
# 3   10113.494317
# 26  -8135.541180
# 16  10833.209476
# 42   1738.143130
# 6   -8339.735590
# 18  -3614.699552
# 5   -5134.131401
# 12  11899.401086
# 39  -1484.743513
# 20   3815.593738
# 38  14379.834945
# 36  16661.530425
# 41   4409.979127
# 8    -241.106065
# 10   9566.805965
# 34   7508.387716
# 35   7626.727206
# 4   -4667.621795
# 15 -17399.502483
# 9   -5075.821349

# %%
sns.distplot(residual2)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ##### normally distributed

# %%
sns.scatterplot(x=residual2.squeeze(),y=y1_pred_train.squeeze())
plt.show()

# %%
df1 = pd.read_csv("50_Startups.csv")
df1.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df = pd.get_dummies(df1['State'],drop_first=True)
df
# Out:
#     Florida  New York
# 0         0         1
# 1         0         0
# 2         1         0
# 3         0         1
# 4         1         0
# 5         0         1
# 6         0         0
# 7         1         0
# 8         0         1
# 9         0         0
# 10        1         0
# 11        0         0
# 12        1         0
# 13        0         0
# 14        1         0
# 15        0         1
# 16        0         0
# 17        0         1
# 18        1         0
# 19        0         1
# 20        0         0
# 21        0         1
# 22        1         0
# 23        1         0
# 24        0         1
# 25        0         0
# 26        1         0
# 27        0         1
# 28        1         0
# 29        0         1
# 30        1         0
# 31        0         1
# 32        0         0
# 33        1         0
# 34        0         0
# 35        0         1
# 36        1         0
# 37        0         0
# 38        0         1
# 39        0         0
# ...

# %%
df = pd.concat([df,df1],axis=1)
df
# Out:
#     Florida  New York  R&D Spend  Administration  Marketing Spend       State  \
# 0         0         1  165349.20       136897.80        471784.10    New York
# 1         0         0  162597.70       151377.59        443898.53  California
# 2         1         0  153441.51       101145.55        407934.54     Florida
# 3         0         1  144372.41       118671.85        383199.62    New York
# 4         1         0  142107.34        91391.77        366168.42     Florida
# 5         0         1  131876.90        99814.71        362861.36    New York
# 6         0         0  134615.46       147198.87        127716.82  California
# 7         1         0  130298.13       145530.06        323876.68     Florida
# 8         0         1  120542.52       148718.95        311613.29    New York
# 9         0         0  123334.88       108679.17        304981.62  California
# 10        1         0  101913.08       110594.11        229160.95     Florida
# ...

# %%
df = df.drop('State',axis=1)
df
# Out:
#     Florida  New York  R&D Spend  Administration  Marketing Spend     Profit
# 0         0         1  165349.20       136897.80        471784.10  192261.83
# 1         0         0  162597.70       151377.59        443898.53  191792.06
# 2         1         0  153441.51       101145.55        407934.54  191050.39
# 3         0         1  144372.41       118671.85        383199.62  182901.99
# 4         1         0  142107.34        91391.77        366168.42  166187.94
# 5         0         1  131876.90        99814.71        362861.36  156991.12
# 6         0         0  134615.46       147198.87        127716.82  156122.51
# 7         1         0  130298.13       145530.06        323876.68  155752.60
# 8         0         1  120542.52       148718.95        311613.29  152211.77
# 9         0         0  123334.88       108679.17        304981.62  149759.96
# 10        1         0  101913.08       110594.11        229160.95  146121.95
# ...

# %%
y = df.pop('Profit')
X = df

# %%
print(y)
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y,train_size=0.7, test_size=0.3, random_state=22)

# %%
X_train
# Out:
#     Florida  New York  R&D Spend  Administration  Marketing Spend
# 23        1         0   67532.53       105751.03        304768.73
# 11        0         0  100671.96        91790.61        249744.55
# 9         0         0  123334.88       108679.17        304981.62
# 10        1         0  101913.08       110594.11        229160.95
# 37        0         0   44069.95        51283.14        197029.42
# 21        0         1   78389.47       153773.43        299737.29
# 7         1         0  130298.13       145530.06        323876.68
# 28        1         0   66051.52       182645.56        118148.20
# 40        0         0   28754.33       118546.05        172795.67
# 19        0         1   86419.70       153514.11             0.00
# 6         0         0  134615.46       147198.87        127716.82
# 17        0         1   94657.16       145077.58        282574.31
# 45        0         1    1000.23       124153.04          1903.93
# ...

# %%
X_test
# Out:
#     Florida  New York  R&D Spend  Administration  Marketing Spend
# 32        0         0   63408.86       129219.61         46085.25
# 12        1         0   93863.75       127320.38        249839.44
# 25        0         0   64664.71       139553.16        137962.62
# 47        0         0       0.00       135426.92             0.00
# 33        1         0   55493.95       103057.49        214634.81
# 22        1         0   73994.56       122782.75        303319.26
# 3         0         1  144372.41       118671.85        383199.62
# 30        1         0   61994.48       115641.28         91131.24
# 26        1         0   75328.87       144135.98        134050.07
# 1         0         0  162597.70       151377.59        443898.53
# 35        0         1   46014.02        85047.44        205517.64
# 41        1         0   27892.92        84710.77        164470.71
# 16        0         0   78013.11       121597.55        264346.06
# ...

# %%
y_train
# Out:
# 23    108733.99
# 11    144259.40
# 9     149759.96
# 10    146121.95
# 37     89949.14
# 21    111313.02
# 7     155752.60
# 28    103282.38
# 40     78239.91
# 19    122776.86
# 6     156122.51
# 17    125370.37
# 45     64926.08
# 2     191050.39
# 48     35673.41
# 27    105008.31
# 15    129917.04
# 5     156991.12
# 42     71498.49
# 34     96712.80
# 39     81005.76
# 24    108552.04
# 14    132602.65
# 18    124266.90
# 29    101004.64
# 46     49490.75
# 31     97483.56
# 8     152211.77
# 20    118474.03
# 43     69758.98
# 38     81229.06
# 36     90708.19
# 0     192261.83
# 44     65200.33
# 4     166187.94
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 32     97427.84
# 12    141585.52
# 25    107404.34
# 47     42559.73
# 33     96778.92
# 22    110352.25
# 3     182901.99
# 30     99937.59
# 26    105733.54
# 1     191792.06
# 35     96479.51
# 41     77798.83
# 16    126992.93
# 49     14681.40
# 13    134307.35
# Name: Profit, dtype: float64

# %%
y_train = np.array(y_train)
y_train = y_train.reshape(-1,1)

# %%
y_test = np.array(y_test)
y_test = y_test.reshape(-1,1)

# %% [markdown]
# ## scaling on dataset

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
y_train_scaled = scaler.fit_transform(y_train)

# %%
y_test_scaled = scaler.transform(y_test)

# %% [markdown]
# ## training multiple linear model on training set

# %%
from sklearn.linear_model import LinearRegression

# %%
lr1 = LinearRegression()

# %%
lr1.fit(X_train_scaled,y_train_scaled)
# Out:
# LinearRegression()

# %% [markdown]
# ## predicting test set results

# %%
y_pred = lr1.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([[-0.29561836],
#        [ 0.41091001],
#        [-0.23864065],
#        [-1.61478537],
#        [-0.37769241],
#        [ 0.02696207],
#        [ 1.43883493],
#        [-0.29842261],
#        [-0.02133867],
#        [ 1.88087816],
#        [-0.62958701],
#        [-0.95426787],
#        [ 0.09205156],
#        [-1.58891555],
#        [ 0.36753682]])

# %%
lr1.coef_
# Out:
# array([[ 0.00113328, -0.02956714,  0.94833836, -0.01373755,  0.04693498]])

# %%
lr1.intercept_
# Out:
# array([1.39034493e-16])

# %% [markdown]
# ###### Y = 54689.16481053 +  (9.49820887e+01*0)  -(2.26215711e+03*0)  + (7.75291986e-01*63408.86) -(1.68989016e-02*129219.61) +  (1.47835925e-02*46085.25)

# %%
pred = 54689.16481053 +  (9.49820887e+01*0)  -(2.26215711e+03*0)  + (7.75291986e-01*63408.86) -(1.68989016e-02*129219.61) + (1.47835925e-02*46085.25)

# %%
pred
# Out:
# 102347.18189200622

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
score = r2_score(y_test_scaled,y_pred)

# %%
score
# Out:
# 0.9394931823665885

# %%
rmse = np.sqrt(mean_squared_error(y_test_scaled,y_pred))

# %%
rmse
# Out:
# 0.24598133594525318

# %% [markdown]
# ## assumptions

# %%
y_pred_train = lr1.predict(X_train_scaled)

# %%
residual = y_train_scaled - y_pred_train
residual
# Out:
# array([[-0.0297417 ],
#        [ 0.2477169 ],
#        [-0.08509577],
#        [ 0.28541664],
#        [-0.02517755],
#        [-0.09828552],
#        [-0.0628438 ],
#        [-0.03621359],
#        [ 0.01865979],
#        [ 0.15697897],
#        [-0.06163285],
#        [-0.05729689],
#        [ 0.36430794],
#        [ 0.34289545],
#        [-0.43049364],
#        [-0.16860338],
#        [-0.34591501],
#        [-0.03583063],
#        [-0.05498325],
#        [ 0.14733376],
#        [-0.1257803 ],
#        [-0.1058318 ],
#        [-0.43101634],
#        [-0.10776339],
#        [-0.03390153],
#        [-0.23106189],
#        [-0.02814629],
#        [ 0.11186709],
#        [ 0.05743872],
#        [ 0.18323816],
#        [ 0.30356854],
#        [ 0.34004861],
#        [ 0.18434398],
#        [-0.11847945],
#        [-0.06971998]])

# %%
sns.distplot(residual)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
y_pred_train
# Out:
# array([[-0.09719112],
#        [ 0.56363166],
#        [ 1.04172268],
#        [ 0.57512476],
#        [-0.59789239],
#        [ 0.0394689 ],
#        [ 1.17774566],
#        [-0.23470474],
#        [-0.95098872],
#        [ 0.08698227],
#        [ 1.18630461],
#        [ 0.36975676],
#        [-1.64827585],
#        [ 1.70427599],
#        [-1.62608281],
#        [-0.05673045],
#        [ 0.77845951],
#        [ 1.18344373],
#        [-1.05539708],
#        [-0.59176492],
#        [-0.73349823],
#        [-0.0259066 ],
#        [ 0.93449198],
#        [ 0.39107891],
#        [-0.29717545],
#        [-1.4605771 ],
#        [-0.3959279 ],
#        [ 0.90951594],
#        [ 0.07287808],
#        [-1.33956166],
#        [-1.15694938],
#        [-0.94307086],
#        [ 1.89482347],
#        [-1.15824509],
#        [ 1.46023542]])

# %% [markdown]
# ## error terms are normally distributed

# %%
plt.scatter(residual,y_pred_train)
plt.show()

# %% [markdown]
# ## Errors are independant and have constant variance

# %% [markdown]
# ## Overfit / Underfit

# %%
y_pred_train = lr1.predict(X_train_scaled)

# %%
y_pred_test = lr1.predict(X_test_scaled)

# %%
score_train =r2_score(y_train_scaled , y_pred_train) 
score_test = r2_score( y_test_scaled , y_pred_test)

# %%
print(score_train,score_test)
# Out:
# 0.9600543528526827 0.9394931823665885
